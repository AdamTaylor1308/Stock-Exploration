# %%
import pandas as pd
import glob
import datetime as datetime

# %%
path = '/Users/adamtaylor/Documents/Personal/Finance/StockDB/yfinGens/Data1.3/stock_metrics_*.csv'
files = glob.glob(path)

date = datetime.datetime.now().strftime('%m%d%y')

df = pd.concat((pd.read_csv(f) for f in files), ignore_index=True)
df.to_csv(f'/Users/adamtaylor/Documents/Personal/Finance/StockDB/yfinGens/Data1.3/merged_data_{date}.csv', index=False)
